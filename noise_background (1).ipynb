# %%
#Mount Drive

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import IPython
# !pip install pysoundfile
# !pip install bitstring

# %%
import IPython
IPython.display.Audio('/content/drive/MyDrive/voice/voice.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import librosa 
import os
import matplotlib.pyplot as plt

def plot_spec(data:np.array,sr:int,title:str, fpath:str) -> None:
  '''
  Function for plotting spectrogram along with amplitude wave graph
  '''
  label = str(fpath).split('/')[-1].split('_')[0]
  fig, ax = plt.subplots(1,2,figsize=(15,5))
  ax[0].title.set_text(f'{title} / Label: {label}')
  ax[0].specgram(data,Fs=2)
  ax[1].set_ylabel('Amplitude')
  ax[1].plot(np.linspace(0,1,len(data)), data)
  
#Reading the wav file:
file_path = "/content/drive/MyDrive/voice/voice.wav"

wav, sr = librosa.load(file_path,sr=None)



#Plotting the spectrogram and wave graph
plot_spec(wav,sr,'Original wave file',file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:7592: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
import IPython
IPython.display.Audio('/content/drive/MyDrive/voice/library-sounds-study.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_path_noise ="/content/drive/MyDrive/voice/library-sounds-study.wav"
wav_noise, sr = librosa.load(file_path_noise,sr=None)

plot_spec(wav_noise,sr,'Original wave file',file_path)

# %%
# !pip install pydub

# %%
from pydub import AudioSegment

sound1 = AudioSegment.from_file("/content/drive/MyDrive/voice/voice.wav")
sound2 = AudioSegment.from_file("/content/drive/MyDrive/voice/library-sounds-study.wav")

combined = sound1.overlay(sound2)

combined.export("/content/drive/MyDrive/voice/combined.wav", format='wav')
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/voice/combined.wav'>

# %%
IPython.display.Audio('/content/drive/MyDrive/voice/combined.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
file_path_noise ="/content/drive/MyDrive/voice/combined.wav"
wav_noise_combined, sr = librosa.load(file_path_noise,sr=None)

plot_spec(wav_noise_combined,sr,'Original wave file',file_path)
